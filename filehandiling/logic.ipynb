# %%
l=[]
def std(name):
    for i in name:
        l.append(i)
    return

# %%
list1 =[]
def percentage(urdu,eng,math):
    a=urdu+eng+math
    pect=round(a/300*100)
    list1.append(pect)
    return pect
