# %%
# %run logic.ipynb
s=["ali","aslam","ajmal"]
std(s)
std('aaa')
print(l)
# Out:
# ['ali', 'aslam', 'ajmal', 'a', 'a', 'a']

# %%
# %run logic.ipynb
percentage(100,70,60)
print(list1)
# Out:
# [76.66666666666667]
